# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random as rd
import matplotlib.pyplot as plt 
import numpy as np

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sims = 7854664

dentro=0

for i in range (sims):
    p_x=rd.uniform(-1,1)
    p_y=rd.uniform(-1,1)

    if p_x**2 + p_y**2 <=1: 
        dentro+=1

pi=(4*dentro)/sims

print(f"El número de aproximación a pi es de. {pi}")
print(f"Con un total de: {dentro} puntos dentro del circulo, mientras que fuera: {sims-dentro}")
# Out:
# El número de aproximación a pi es de. 3.140705191208688
# Con un total de: 6167296 puntos dentro del circulo, mientras que fuera: 1687368

# %%
"""
Este código realiza una simulación Montecarlo para la aproximación del número pi usando simplemente la gerenación
de número aleatorios distribuidos uniformemente para poprterios a su generación. 
Puedan ser estos mismos datos graficados usando la libreria matplotlib, haciendo un a distinción
entre aquellos pares de puntos que ingresarón en el círculo """

sims=451000

dentro_x = []
dentro_y = []
fuera_x = []  # Asegúrate de haber definido la lista fuera_x
fuera_y = []


for i in range (sims):
    p_x=rd.uniform(-1,1)
    p_y=rd.uniform(-1,1)

    if p_x**2 + p_y**2 <=1: 
        dentro_x.append(p_x)
        dentro_y.append(p_y)
    else:
        fuera_x.append(p_x)
        fuera_y.append(p_y)

pi=(4*len(dentro_x))/sims

print(f"El número de aproximación a pi es de. {pi}")
print(f"Con un total de: {len(dentro_x)} puntos dentro del circulo")

plt.figure(figsize=(5, 5))
plt.scatter(dentro_x, dentro_y, color='yellow', label='Dentro del círculo') 
"""Scatter realiza un gráfico de dispersiones basandose en 4 entradas en su argumento
    la primera es la entrada en x, la entrada en y, el color que se le asigne a ese grafo
    Posterior a ello una etiqueta que permita identificar esos puntos, dicha etiqueta se libera cuando tiramos el comando plt.legend()"""
                                                                            
plt.scatter(fuera_x, fuera_y, color='blue', label='Fuera del círculo')
plt.xlabel('Coordenada X') #etiqueta o titulo para el eje x
plt.ylabel('Coordenada Y')
plt.title('Puntos dentro y fuera del círculo') #Titulo del gráfico
plt.legend(loc='lower right', title='Leyenda')  #Se libera la leyenda que se les puso al scatter, junto con demás argumentos que editan estas leyendas
plt.gca().set_aspect('equal', adjustable='box') #set_aspect establece la relación de escala entre el eje x y y 
# adjustable='box' indica que si la escala de ejes cambia el aspecto se mantiene fijo y se ajustrá usando un delimitador cuadrado dentro del grafo-
plt.show()
# Out:
# El número de aproximación a pi es de. 3.1433968957871397
# Con un total de: 354418 puntos dentro del circulo
